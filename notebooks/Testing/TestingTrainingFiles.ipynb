# %%
import jax
import jax.numpy as np
import os

# %%
training_data_path  = os.path.dirname('_data/autoencoder/training_data/')
emnist_path         = os.path.join(training_data_path, 'emnist.npz')
mnist_path          = os.path.join(training_data_path, 'mnist.npz')
ppd_51_path         = os.path.join(training_data_path, 'fake_intensity_PPDs_51x51.npz')

# %%
emnist  = np.load(emnist_path)
mnist   = np.load(mnist_path)
ppd_51  = np.load(ppd_51_path)

# %%
emnist
# Out:
# NpzFile '_data/autoencoder/training_data/emnist.npz' with keys: x_train, y_train, x_test, y_test

# %%
mnist
# Out:
# NpzFile '_data/autoencoder/training_data/mnist.npz' with keys: x_test, x_train, y_train, y_test

# %%
ppd_51
# Out:
# NpzFile '_data/autoencoder/training_data/fake_intensity_PPDs_51x51.npz' with keys: x_train, x_test
